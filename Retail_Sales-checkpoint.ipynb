# %%
import pandas as pd
df = pd.read_csv('retail_sales_data.csv')
df
# Out:
#     Order_ID  Order_Date Customer_ID Customer_Name Product_Category  \
# 0    ORD1000  2023-01-01     CUST754         Manoj      Electronics
# 1    ORD1001  2023-01-01     CUST214         Nimal  Home Appliances
# 2    ORD1002  2023-01-02     CUST125        Anjali             Toys
# 3    ORD1003  2023-01-03     CUST859       Praveen             Toys
# 4    ORD1004  2023-01-03     CUST381      Tharindu      Electronics
# ..       ...         ...         ...           ...              ...
# 995  ORD1995  2024-12-28     CUST750         Manoj         Clothing
# 996  ORD1996  2024-12-28     CUST948         Kavya             Toys
# 997  ORD1997  2024-12-29     CUST570    Sutharsiga      Electronics
# 998  ORD1998  2024-12-30     CUST824        Ramesh      Electronics
# 999  ORD1999  2024-12-31     CUST256        Dilani            Books
#
#     Product_Name  Quantity  Unit_Price  Total_Sales      Region Payment_Method
# ...

# %%
import matplotlib.pyplot as plt

# %%
print(df.head())
# Out:
#   Order_ID  Order_Date Customer_ID Customer_Name Product_Category  \
# 0  ORD1000  2023-01-01     CUST754         Manoj      Electronics
# 1  ORD1001  2023-01-01     CUST214         Nimal  Home Appliances
# 2  ORD1002  2023-01-02     CUST125        Anjali             Toys
# 3  ORD1003  2023-01-03     CUST859       Praveen             Toys
# 4  ORD1004  2023-01-03     CUST381      Tharindu      Electronics
#
#   Product_Name  Quantity  Unit_Price  Total_Sales      Region Payment_Method
# 0       Tablet         1     2042.62      2042.62       Galle           Cash
# 1          Fan         6     1200.24      7201.44       Galle           Cash
# 2       Puzzle         3      774.24      2322.72       Galle           Card
# 3         Doll         8     2298.15     18385.20     Colombo           Cash
# 4   Headphones         4     4191.32     16765.28  Kurunegala         Online

# %%
print(df.isnull().sum())
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Customer_Name       0
# Product_Category    0
# Product_Name        0
# Quantity            0
# Unit_Price          0
# Total_Sales         0
# Region              0
# Payment_Method      0
# Month_Year          0
# dtype: int64

# %%
print(df.shape)
# Out:
# (1000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   object
#  1   Order_Date        1000 non-null   datetime64[ns]
#  2   Customer_ID       1000 non-null   object
#  3   Customer_Name     1000 non-null   object
#  4   Product_Category  1000 non-null   object
#  5   Product_Name      1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Unit_Price        1000 non-null   float64
#  8   Total_Sales       1000 non-null   float64
#  9   Region            1000 non-null   object
#  10  Payment_Method    1000 non-null   object
#  11  Month_Year        1000 non-null   period[M]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7), period[M](1)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#                        Order_Date     Quantity   Unit_Price   Total_Sales
# count                        1000  1000.000000  1000.000000   1000.000000
# mean   2023-12-31 12:01:26.400000     5.550000  2536.329420  14235.175610
# min           2023-01-01 00:00:00     1.000000   100.960000    240.280000
# 25%           2023-07-01 18:00:00     3.000000  1313.837500   4417.512500
# 50%           2023-12-31 12:00:00     6.000000  2487.200000  10975.635000
# 75%           2024-07-01 06:00:00     8.000000  3753.590000  21484.885000
# max           2024-12-31 00:00:00    10.000000  4987.600000  49739.300000
# std                           NaN     2.885451  1404.493671  11650.617567

# %%
df['Month_Year'] = df['Order_Date'].dt.to_period('M')

# %%
category_sales = df.groupby('Product_Category')['Total_Sales'].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Product_Category
# Electronics        2751590.55
# Toys               2603218.36
# Home Appliances    2437239.27
# Books              2402034.17
# Groceries          2182376.52
# Clothing           1858716.74
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize=(8,5))
category_sales.plot(kind='bar', color='skyblue')
plt.title('Sales by Product Category')
plt.ylabel('Total Sales')
plt.show()

# %%
top_products = df.groupby('Product_Name')['Total_Sales'].sum().sort_values(ascending=False).head(10)
print(top_products)
# Out:
# Product_Name
# Headphones         742687.00
# Laptop             706805.86
# Ball               690530.35
# Mixer              587041.50
# Car Toy            583430.35
# Washing Machine    521377.25
# Fan                520601.46
# Textbook           516450.96
# Notebook           507630.63
# Puzzle             499258.19
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize=(8,5))
top_products.plot(kind='barh', color='orange')
plt.title('Top 10 Products by Sales')
plt.xlabel('Total Sales')
plt.gca().invert_yaxis()  # Highest on top
plt.show()

# %%
top_customers = df.groupby('Customer_Name')['Total_Sales'].sum().sort_values(ascending=False).head(10)
print(top_customers)
# Out:
# Customer_Name
# Ramesh        1884667.58
# Kavya         1745439.23
# Praveen       1581781.93
# Tharindu      1508745.86
# Anjali        1438214.05
# Dilani        1348324.33
# Sutharsiga    1324886.42
# Nimal         1178677.80
# Manoj         1139513.19
# Arjun         1084925.22
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize=(8,5))
top_customers.plot(kind='barh', color='green')
plt.title('Top 10 Customers by Revenue')
plt.xlabel('Total Sales')
plt.gca().invert_yaxis()
plt.show()

# %%
region_sales = df.groupby('Region')['Total_Sales'].sum()
print(region_sales)
# Out:
# Region
# Colombo       2346406.28
# Galle         2402405.34
# Jaffna        2153069.72
# Kandy         2040288.91
# Kurunegala    2571622.07
# Matara        2721383.29
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize=(10,5))
monthly_sales.plot(kind='line', marker='o')
plt.title('Monthly Sales Trend')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
monthly_sales = df.groupby('Month_Year')['Total_Sales'].sum()
print(monthly_sales)
# Out:
# Month_Year
# 2023-01    523005.82
# 2023-02    604943.36
# 2023-03    557043.11
# 2023-04    877855.33
# 2023-05    577867.62
# 2023-06    559815.85
# 2023-07    470722.27
# 2023-08    506416.86
# 2023-09    556173.06
# 2023-10    678961.93
# 2023-11    671729.29
# 2023-12    677956.27
# 2024-01    507377.72
# 2024-02    540179.66
# 2024-03    686752.01
# 2024-04    504915.72
# 2024-05    633280.27
# 2024-06    600992.00
# 2024-07    619354.06
# 2024-08    628450.70
# 2024-09    539571.02
# 2024-10    542207.89
# 2024-11    550187.53
# 2024-12    619416.26
# Freq: M, Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize=(8,5))
region_sales.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Sales by Region')
plt.ylabel('')
plt.show()

# %%
payment_sales = df.groupby('Payment_Method')['Total_Sales'].sum().sort_values(ascending=False)
print(payment_sales)
# Out:
# Payment_Method
# Cash      5052111.17
# Online    4972099.29
# Card      4210965.15
# Name: Total_Sales, dtype: float64

# %%
plt.figure(figsize=(6,4))
payment_sales.plot(kind='bar', color=['orange','green','blue'])
plt.title('Total Sales by Payment Method')
plt.ylabel('Total Sales')
plt.xlabel('Payment Method')
plt.show()

# %%
payment_counts = df['Payment_Method'].value_counts()
print(payment_counts)
# Out:
# Payment_Method
# Online    357
# Cash      340
# Card      303
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
payment_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['orange','green','blue'])
plt.title('Payment Method Usage (Orders)')
plt.ylabel('')
plt.show()
